# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# %%
SGA = Table.read("/global/homes/b/barnerg/DESI_SGA/Morphology/SGA_morph.fits")

# %%
SGA
# Out:
# <Table length=383620>
#  SGA_ID    SGA_GALAXY    ...      C_r20_r90       HUBBLE_TYPE
#  int64      bytes16      ...       float64          float64
# ------- ---------------- ... -------------------- -----------
#  284583  SGA-2020 284583 ...  0.02908896399400337        -5.0
#  202259  SGA-2020 202259 ...  0.02361333846336491        -5.0
# 1376538 SGA-2020 1376538 ...   0.0747298970698173        -5.0
#  117296  SGA-2020 117296 ...  0.06394047676502324        -5.0
# 1098679 SGA-2020 1098679 ... 0.024509579536889394        -5.0
#  972626  SGA-2020 972626 ...  0.03606050432792272        -5.0
# 1098672 SGA-2020 1098672 ...                   --        -5.0
# 1376529 SGA-2020 1376529 ... 0.035802372986897535        -5.0
#  202246  SGA-2020 202246 ...  0.05789567420890143        -5.0
# 1376540 SGA-2020 1376540 ... 0.030630557154369138        -5.0
#     ...              ... ...                  ...         ...
#  595353  SGA-2020 595353 ...   0.2867407961728481          --
# ...

# %%
SGA['HUBBLE_TYPE'].mask
# Out:
# array([False, False, False, ...,  True,  True,  True])

# %%
E = SGA[SGA['HUBBLE_TYPE']==-5.0]

# %%
L = SGA[(SGA['HUBBLE_TYPE']==-2.0) | (SGA['HUBBLE_TYPE']==0)]

# %%
Sa = SGA[SGA['HUBBLE_TYPE']==1.0]

# %%
Sb = SGA[(SGA['HUBBLE_TYPE']==2.0) | (SGA['HUBBLE_TYPE']==3.0) | (SGA['HUBBLE_TYPE']==4.0)]

# %%
Sc = SGA[(SGA['HUBBLE_TYPE']==5.0) | (SGA['HUBBLE_TYPE']==6.0) | (SGA['HUBBLE_TYPE']==7.0)]

# %%
I = SGA[SGA['HUBBLE_TYPE']==9.0]

# %%
Nonclass= SGA[(SGA['HUBBLE_TYPE']<-5.0) | (SGA['HUBBLE_TYPE']>9.0)]

# %%
Nonclass = SGA[SGA['HUBBLE_TYPE'].mask]

# %%
gr = SGA['g_r']
rz = SGA['r_z']
gz = SGA['g_z']
C59 = SGA['C_r50_r90']
C29 = SGA['C_r20_r90']

# %%
plt.scatter(Nonclass['g_z'], Nonclass['C_r50_r90'], c='tab:gray', alpha=0.1)
plt.scatter(E['g_z'], E['C_r50_r90'], c='#ff0000', alpha=0.1)
plt.scatter(L['g_z'], L['C_r50_r90'], c='tab:orange', alpha=0.1)
plt.scatter(Sb['g_z'], Sb['C_r50_r90'], c='y', alpha=0.1)
plt.scatter(Sa['g_z'], Sa['C_r50_r90'], c='g', alpha=0.1)
plt.scatter(Sc['g_z'], Sc['C_r50_r90'], c='c', alpha=0.1)
plt.scatter(I['g_z'], I['C_r50_r90'], c='tab:purple', alpha=0.1)
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.title('Color(g - z) v. Concentration Index(C (r50/r90))')
plt.xlabel('g - z')
plt.ylabel('C (r50/r90)')
plt.xticks(np.arange(-7, 10, 1))
plt.yticks(np.arange(0,1.1,0.1))

plt.savefig('Color(g_z)vConcentration(C_r50_r90).png')
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[242], line 15
#      12 plt.xticks(np.arange(-7, 10, 1))
#      13 plt.yticks(np.arange(0,1.1,0.1))
# ---> 15 plt.legend('Nonclass','E','L')
#      16 plt.savefig('Color(g_z)vConcentration(C_r50_r90).png')
#      17 plt.show()
#
# File /global/common/software/desi/perlmutter/desiconda/20230111-2.1.0/conda/lib/python3.10/site-packages/matplotlib/pyplot.py:2638, in legend(*args, **kwargs)
#    2636 @_copy_docstring_and_deprecators(Axes.legend)
#    2637 def legend(*args, **kwargs):
# -> 2638     return gca().legend(*args, **kwargs)
#
# File /global/common/software/desi/perlmutter/desiconda/20230111-2.1.0/conda/lib/python3.10/site-packages/matplotlib/axes/_axes.py:306, in Axes.legend(self, *args, **kwargs)
#     301 handles, labels, extra_args, kwargs = mlegend._parse_legend_args(
#     302         [self],
# ...

# %%
plt.scatter(Nonclass['g_z'], Nonclass['C_r20_r90'], c='tab:gray', alpha=0.1)
plt.scatter(E['g_z'], E['C_r20_r90'], c='#ff0000', alpha=0.1)
plt.scatter(L['g_z'], L['C_r20_r90'], c='tab:orange', alpha=0.1)
plt.scatter(Sb['g_z'], Sb['C_r20_r90'], c='y', alpha=0.1)
plt.scatter(Sa['g_z'], Sa['C_r20_r90'], c='g', alpha=0.1)
plt.scatter(Sc['g_z'], Sc['C_r20_r90'], c='c', alpha=0.1)
plt.scatter(I['g_z'], I['C_r20_r90'], c='tab:purple', alpha=0.1)


plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.title('Color(g - z) v. Concentration Index(C (r20/r90))')
plt.xlabel('g - z')
plt.ylabel('C (r20/r90)')
plt.xticks(np.arange(-4, 6, 1))
plt.yticks(np.arange(0,1.1,0.1))

plt.savefig('Color(g_z)vConcentration(C_r20_r90).png')
plt.show()
plt.close()

# %%
plt.scatter(Nonclass['r_z'], Nonclass['C_r50_r90'], c='tab:gray', alpha=0.1)
plt.scatter(E['r_z'], E['C_r50_r90'], c='#ff0000', alpha=0.1)
plt.scatter(L['r_z'], L['C_r50_r90'], c='tab:orange', alpha=0.1)
plt.scatter(Sb['r_z'], Sb['C_r50_r90'], c='y', alpha=0.1)
plt.scatter(Sa['r_z'], Sa['C_r50_r90'], c='g', alpha=0.1)
plt.scatter(Sc['r_z'], Sc['C_r50_r90'], c='c', alpha=0.1)
plt.scatter(I['r_z'], I['C_r50_r90'], c='tab:purple', alpha=0.1)
#plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.title('Color(r - z) v. Concentration Index(C (r50/r90))')
plt.xlabel('r - z')
plt.ylabel('C (r50/r90)')
plt.xticks(np.arange(-7, 9, 1))
plt.yticks(np.arange(0,1.1,0.1))

plt.savefig('Color(r_z)vConcentration(C_r50_r90).png')
plt.show()
plt.close()

# %%
plt.scatter(Nonclass['r_z'], Nonclass['C_r20_r90'], c='tab:gray', alpha=0.1)
plt.scatter(E['r_z'], E['C_r20_r90'], c='#ff0000', alpha=0.1)
plt.scatter(L['r_z'], L['C_r20_r90'], c='tab:orange', alpha=0.1)
plt.scatter(Sb['r_z'], Sb['C_r20_r90'], c='y', alpha=0.1)
plt.scatter(Sa['r_z'], Sa['C_r20_r90'], c='g', alpha=0.1)
plt.scatter(Sc['r_z'], Sc['C_r20_r90'], c='c', alpha=0.1)
plt.scatter(I['r_z'], I['C_r20_r90'], c='tab:purple', alpha=0.1)
#plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.title('Color(r - z) v. Concentration Index(C (r20/r90)')
plt.xlabel('r - z')
plt.ylabel('C (r20/r90)')
plt.xticks(np.arange(-7, 9, 1))
plt.yticks(np.arange(0,1.1,0.1))

plt.savefig('Color(r_z)vConcentration(C_r20_r90).png')
plt.show()
plt.close()

# %%
plt.scatter(Nonclass['g_r'], Nonclass['C_r50_r90'], c='tab:gray', alpha=0.1)
plt.scatter(E['g_r'], E['C_r50_r90'], c='#ff0000', alpha=0.1)
plt.scatter(L['g_r'], L['C_r50_r90'], c='tab:orange', alpha=0.1)
plt.scatter(Sb['g_r'], Sb['C_r50_r90'], c='y', alpha=0.1)
plt.scatter(Sa['g_r'], Sa['C_r50_r90'], c='g', alpha=0.1)
plt.scatter(Sc['g_r'], Sc['C_r50_r90'], c='c', alpha=0.1)
plt.scatter(I['g_r'], I['C_r50_r90'], c='tab:purple', alpha=0.1)
#plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.title('Color(g - r) v. Concentration Index(C (r50/r90))')
plt.xlabel('g - r')
plt.ylabel('C (r50/r90)')
plt.xticks(np.arange(-6, 11, 1))
plt.yticks(np.arange(0,1.1,0.1))

plt.savefig('Color(g_r)vConcentration(C_r50_r90).png')
plt.show()
plt.close()

# %%
plt.scatter(Nonclass['g_r'], Nonclass['C_r20_r90'], c='tab:gray', alpha=0.1)
plt.scatter(E['g_r'], E['C_r20_r90'], c='#ff0000', alpha=0.1)
plt.scatter(L['g_r'], L['C_r20_r90'], c='tab:orange', alpha=0.1)
plt.scatter(Sb['g_r'], Sb['C_r20_r90'], c='y', alpha=0.1)
plt.scatter(Sa['g_r'], Sa['C_r20_r90'], c='g', alpha=0.1)
plt.scatter(Sc['g_r'], Sc['C_r20_r90'], c='c', alpha=0.1)
plt.scatter(I['g_r'], I['C_r20_r90'], c='tab:purple', alpha=0.1)
#plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.title('Color(g - r) v. Concentration Index(C (r20/r90))')
plt.xlabel('g - r')
plt.ylabel('C (r20/r90)')
plt.xticks(np.arange(-6, 11, 1))
plt.yticks(np.arange(0,1.1,0.1))

plt.savefig('Color(g_r)vConcentration(C_r20_r90).png')
plt.show()
plt.close()
