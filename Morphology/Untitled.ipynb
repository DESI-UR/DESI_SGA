# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
import numpy

# %%
SGA = Table.read("/Users/gracebarner/Downloads/SGA-2020.fits")

# %%
unique = np.unique(SGA['MORPHTYPE'])
with np.printoptions(threshold=sys.maxsize):
    print(unique)
# Out:
# MORPHTYPE
# ---------
#
#   .E+..?.
#   .E+..P*
#   .E+4...
#   .E...P*
#   .I..9P.
#   .IBS9..
#       ...
#       Scd
#        Sd
#        Sm
#      dIrr
# dIrr/dSph
#      dSph
#     dSph?
# Length = 65 rows

# %%
#np.unique(SGA['MORPHTYPE'])
unique, counts = np.unique(SGA['MORPHTYPE'], return_counts=True)

# %%
unique = np.unique(SGA['MORPHTYPE'], return_counts=True)
print(unique)
# Out:
# (<MaskedColumn name='MORPHTYPE' dtype='bytes21' length=65>
#
#   .E+..?.
#   .E+..P*
#   .E+4...
#   .E...P*
#   .I..9P.
#   .IBS9..
#   .L..+P*
#   .L?....
#       ...
#        Sc
#       Scd
#        Sd
#        Sm
#      dIrr
# dIrr/dSph
#      dSph
#     dSph?, array([     3,      1,      3,      1,      1,      1,      2,      1,
#             1,      1,      1,      1,      1,      2,      1,      1,
#             1,      1,      1,      1,     35,   1320,      1,   1117,
#             1,      5,  45468,   3251,  11137,     26,   2374,    118,
#           270,      1, 169164,    419,      2,   4749,  14527,  39252,
#           330,    771,    804,    141,    129,    957,   1492,   3463,
#          3763,   3473,    783,    499,    459,   2887,   5990,  11076,
#         17294,  28455,   3382,   2470,   1712,     15,      6,      5,
#             1]))

# %%
SGA['MORPHTYPE'][SGA['MORPHTYPE'] == 'PSF'] = np.nan
SGA['MORPHTYPE'][SGA['MORPHTYPE'] == 'nan'] = np.nan
SGA['MORPHTYPE'][SGA['MORPHTYPE'] == ' '] = np.nan
SGA['MORPHTYPE'][SGA['MORPHTYPE'] == '  '] = np.nan
SGA['MORPHTYPE'][SGA['MORPHTYPE'] == 'COMP'] = np.nan
SGA['MORPHTYPE'][SGA['MORPHTYPE'] == 'DEV'] = np.nan
SGA['MORPHTYPE'][SGA['MORPHTYPE'] == 'DLX.0..'] = np.nan
SGA['MORPHTYPE'][SGA['MORPHTYPE'] == 'DUP'] = np.nan
SGA['MORPHTYPE'][SGA['MORPHTYPE'] == 'PSF'] = np.nan
SGA['MORPHTYPE'][SGA['MORPHTYPE'] == 'REX'] = np.nan

# %%
numpy.set_printoptions(threshold=sys.maxsize)
print(SGA['MORPHTYPE'])
# Out:
# MORPHTYPE
# ---------
#        S?
#        Sc
#        S?
#       Sbc
#         E
#        S?
#        S?
#       ...
#       nan
#       nan
#       nan
#       nan
#       nan
#       nan
#       nan
# Length = 383620 rows

# %%
SGA
# Out:
# <Table length=383620>
#  SGA_ID    SGA_GALAXY    ... Z_COG_PARAMS_CHI2 ELLIPSEBIT
#  int64      bytes16      ...      float32        int32
# ------- ---------------- ... ----------------- ----------
#       2       SGA-2020 2 ...       0.011723555          0
#       3       SGA-2020 3 ...        0.20391206          0
#       4       SGA-2020 4 ...         1.8054093          0
#       7       SGA-2020 7 ...       0.004725194          0
#      18      SGA-2020 18 ...       0.028653827          0
#      20      SGA-2020 20 ...        0.97457016          0
#     ...              ... ...               ...        ...
# 5005221 SGA-2020 5005221 ...       0.042753268          0
# 5005223 SGA-2020 5005223 ...       0.015200222          0
# 5005230 SGA-2020 5005230 ...       0.011277596          0
# 5005238 SGA-2020 5005238 ...        0.03202154          0
# 5005241 SGA-2020 5005241 ...       0.004562201          0
# 5005244 SGA-2020 5005244 ...         0.1392315          0
# ...

# %%
unique, counts = np.unique(SGA['MORPHTYPE'], return_counts=True)
print(unique, counts)
# Out:
# MORPHTYPE
# ---------
#   .E+..?.
#   .E+..P*
#   .E+4...
#   .E...P*
#   .I..9P.
#   .IBS9..
#   .L..+P*
#       ...
#        Sd
#        Sm
#      dIrr
# dIrr/dSph
#      dSph
#     dSph?
#       nan
# Length = 59 rows [     1      3      1      1      1      2      1      1      1      1
#       1      1      2      1      1      1      1      1      1     35
#       1  45468   3251  11137     26   2374    118    270      1 169164
#    4749  14527  39252    330    771    804    141    129    957   1492
#    3463   3763   3473    783    499    459   2887   5990  11076  17294
#   28455   3382   2470   1712     15      6      5      1   2867]

# %%
key = 'S'
spiral = np.array([])
j= 0
count =0
while j < len(SGA['MORPHTYPE']):
    if (key in SGA['MORPHTYPE'][j] !=False):
        count+=1
        spiral = np.append(spiral,j)
j+=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [130], in <cell line: 5>()
#       4 count =0
#       5 while j < len(SGA['MORPHTYPE']):
# ----> 6     if (key in MORPHTYPE[j] !=False):
#       7         count+=1
#       8         spiral = np.append(spiral,j)
#
# TypeError: a bytes-like object is required, not 'str'
