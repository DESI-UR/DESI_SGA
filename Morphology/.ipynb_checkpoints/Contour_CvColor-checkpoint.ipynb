# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np

# %%
SGA = Table.read("/global/homes/b/barnerg/DESI_SGA/Morphology/SGA_morph.fits")

# %%
SGA
# Out:
# <Table length=383620>
#  SGA_ID    SGA_GALAXY    ...       Delta(r_z)      HUBBLE_TYPE
#  int64      bytes16      ...        float64          float64
# ------- ---------------- ... --------------------- -----------
#  284583  SGA-2020 284583 ...   0.01646960745569581        -5.0
#  202259  SGA-2020 202259 ...  0.048264253920018874        -5.0
# 1376538 SGA-2020 1376538 ...  0.016982929948389458        -5.0
#  117296  SGA-2020 117296 ...   0.22130578696915038        -5.0
# 1098679 SGA-2020 1098679 ...  0.039362173807940604        -5.0
#  972626  SGA-2020 972626 ... -0.029865577907008944        -5.0
# 1098672 SGA-2020 1098672 ...                    --        -5.0
# 1376529 SGA-2020 1376529 ...   0.12520951601549424        -5.0
#  202246  SGA-2020 202246 ...  0.010411535418852313        -5.0
# 1376540 SGA-2020 1376540 ...  -0.01094517863393385        -5.0
#     ...              ... ...                   ...         ...
#  595353  SGA-2020 595353 ... -0.003411049661020016          --
#  595349  SGA-2020 595349 ...  -0.06832868789643465          --
#  595347  SGA-2020 595347 ...                    --          --
#  595342  SGA-2020 595342 ...  0.008248434692862183          --
#  595340  SGA-2020 595340 ... -0.007808970931418191          --
#  595338  SGA-2020 595338 ... -0.027721844991108746          --
#  595334  SGA-2020 595334 ...  0.010990206022439608          --
#  595333  SGA-2020 595333 ... -0.013101865472575192          --
#  595251  SGA-2020 595251 ...   0.02427612661451617          --
# 5005247 SGA-2020 5005247 ... -0.017425842668176372          --

# %%
bool_index1 = np.isfinite(SGA['C_r20_r90'])
bool_index2 = np.isfinite(SGA['g_r'])

good_indices = bool_index1 & bool_index2
SGA = SGA[good_indices]

# %%
E = SGA[SGA['HUBBLE_TYPE']==-5.0]
L = SGA[(SGA['HUBBLE_TYPE']==-2.0) | (SGA['HUBBLE_TYPE']==0)]
Sb = SGA[(SGA['HUBBLE_TYPE']==2.0) | (SGA['HUBBLE_TYPE']==3.0) | (SGA['HUBBLE_TYPE']==4.0)]
S =  SGA[(SGA['HUBBLE_TYPE']==1.0) | (SGA['HUBBLE_TYPE']==5.0) | (SGA['HUBBLE_TYPE']==6.0) | (SGA['HUBBLE_TYPE']==7.0)]
I = SGA[SGA['HUBBLE_TYPE']==9.0]
Nonclass= SGA[(SGA['HUBBLE_TYPE']<-5.0) | (SGA['HUBBLE_TYPE']>9.0)]
Nonclass = SGA[SGA['HUBBLE_TYPE'].mask]

# %%
x = E['C_r20_r90']
y = E['g_r']
a = L['C_r20_r90']
b = L['g_r']
c = Sb['C_r20_r90']
d = Sb['g_r']
e = S['C_r20_r90']
f = S['g_r']
g = I['C_r20_r90']
h = I['g_r']
i = Nonclass['C_r20_r90']
j = Nonclass['g_r']

# %%
'''x,y = np.meshgrid(x,y)

X = np.linspace(0, 1, 10)
Y = np.linspace(0, 1, 10)

x,y = np.meshgrid(X,Y)

f1 = np.cos(x*y)
f2 = x-y
#f1 = np.histogram2d(x,y,bins=600)

plt.contourf(x,y,f2)
#plt.contourf(x,y,f1,colors='blue')
#plt.show()'''
# Out:
# "x,y = np.meshgrid(x,y)\n\nX = np.linspace(0, 1, 10)\nY = np.linspace(0, 1, 10)\n\nx,y = np.meshgrid(X,Y)\n\nf1 = np.cos(x*y)\nf2 = x-y\n#f1 = np.histogram2d(x,y,bins=600)\n\nplt.contourf(x,y,f2)\n#plt.contourf(x,y,f1,colors='blue')\n#plt.show()"

# %%
hist, xedges, yedges= np.histogram2d(i, j, bins=100)
Xedges, Yedges = np.meshgrid(xedges[:-1], yedges[:-1])
plt.contour(Xedges, Yedges, hist.T,colors='red', levels=10, alpha=0.5)
#plt.colorbar()

hist, xedges, yedges= np.histogram2d(x, y, bins=100)
Xedges, Yedges = np.meshgrid(xedges[:-1], yedges[:-1])
plt.contour(xedges[:-1], yedges[:-1], hist.T, colors='blue',levels=10, alpha=0.5)
#plt.colorbar()

hist, xedges, yedges= np.histogram2d(a, b, bins=100)
Xedges, Yedges = np.meshgrid(xedges[:-1], yedges[:-1])
plt.contour(xedges[:-1], yedges[:-1], hist.T, colors='yellow', levels=10, alpha=0.5)
#plt.colorbar() 

hist, xedges, yedges= np.histogram2d(c, d, bins=100)
Xedges, Yedges = np.meshgrid(xedges[:-1], yedges[:-1])
plt.contour(xedges[:-1], yedges[:-1], hist.T,colors='orange', levels=10, alpha=0.5)
#plt.colorbar() 

hist, xedges, yedges= np.histogram2d(e, f, bins=100)
Xedges, Yedges = np.meshgrid(xedges[:-1], yedges[:-1])
plt.contour(xedges[:-1], yedges[:-1], hist.T,colors='green', levels=10, alpha=0.5)
#plt.colorbar() 

hist, xedges, yedges= np.histogram2d(g, h, bins=100)
Xedges, Yedges = np.meshgrid(xedges[:-1], yedges[:-1])
plt.contour(xedges[:-1], yedges[:-1], hist.T,colors='black', levels=10, alpha=0.1)
#plt.colorbar() '''


# Set labels and title
legend = plt.legend(loc='upper right')
plt.xlabel('C (r20/r90)')
plt.ylabel('g_r')
plt.title('Contour Plot (2D Histogram)')
plt.axis([0.1, 0.6, 0, 1.5])
plt.show()
plt.close()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
hist, xedges, yedges= np.histogram2d(g, h, bins=100)
Xedges, Yedges = np.meshgrid(xedges[:-1], yedges[:-1])
plt.contour(xedges[:-1], yedges[:-1], hist.T,colors='purple',label='Irregular (purple)', levels=10)
#plt.colorbar()

hist, xedges, yedges= np.histogram2d(i, j, bins=100)
Xedges, Yedges = np.meshgrid(xedges[:-1], yedges[:-1])
plt.contour(Xedges, Yedges, hist.T,colors='grey',label='No class (grey)',levels=10)
#plt.colorbar()

hist, xedges, yedges= np.histogram2d(x, y, bins=100)
Xedges, Yedges = np.meshgrid(xedges[:-1], yedges[:-1])
plt.contour(xedges[:-1], yedges[:-1], hist.T, colors='blue',label = 'Elliptical (blue)',levels=10)
#plt.colorbar()

hist, xedges, yedges= np.histogram2d(a, b, bins=100)
Xedges, Yedges = np.meshgrid(xedges[:-1], yedges[:-1])
plt.contour(xedges[:-1], yedges[:-1], hist.T, colors='yellow',label = 'Lenticular (yellow)', levels=10)
#plt.colorbar() 

hist, xedges, yedges= np.histogram2d(c, d, bins=100)
Xedges, Yedges = np.meshgrid(xedges[:-1], yedges[:-1])
plt.contour(xedges[:-1], yedges[:-1], hist.T,colors='green',label='Barred Spiral (green)', levels=10)
#plt.colorbar() 

hist, xedges, yedges= np.histogram2d(e, f, bins=100)
Xedges, Yedges = np.meshgrid(xedges[:-1], yedges[:-1])
plt.contour(xedges[:-1], yedges[:-1], hist.T,colors='red',label='Unbarred Spiral (red)', levels=10)
#plt.colorbar() 
 
legend = plt.legend(loc='upper right')
plt.xlabel('C (r20/r90)')
plt.ylabel('g_r')
plt.title('Contour Plot (2D Histogram)')
plt.axis([0.1, 0.6, 0, 1.5])
plt.show()
plt.close()
# Out:
# /tmp/ipykernel_2309651/3106957046.py:3: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(xedges[:-1], yedges[:-1], hist.T,colors='purple',label='Irregular (purple)', levels=10)
# /tmp/ipykernel_2309651/3106957046.py:8: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(Xedges, Yedges, hist.T,colors='grey',label='No class (grey)',levels=10)
# /tmp/ipykernel_2309651/3106957046.py:13: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(xedges[:-1], yedges[:-1], hist.T, colors='blue',label = 'Elliptical (blue)',levels=10)
# /tmp/ipykernel_2309651/3106957046.py:18: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(xedges[:-1], yedges[:-1], hist.T, colors='yellow',label = 'Lenticular (yellow)', levels=10)
# /tmp/ipykernel_2309651/3106957046.py:23: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(xedges[:-1], yedges[:-1], hist.T,colors='green',label='Barred Spiral (green)', levels=10)
# /tmp/ipykernel_2309651/3106957046.py:28: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(xedges[:-1], yedges[:-1], hist.T,colors='red',label='Unbarred Spiral (red)', levels=10)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
