# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np

# %%
SGA_Cindex = Table.read("/global/homes/b/barnerg/DESI_SGA/Morphology/SGA_Cindex.fits")

# %%
SGA_Cindex
# Out:
# <Table length=383620>
#  SGA_ID    SGA_GALAXY    ...      C_r50_r90             C_r20_r90
#  int64      bytes16      ...       float64               float64
# ------- ---------------- ... -------------------- ---------------------
#       2       SGA-2020 2 ...   0.3569852600618256   0.11211049543275872
#       3       SGA-2020 3 ...   0.4020130617027366   0.21711269027456045
#       4       SGA-2020 4 ...   0.4410080066429095   0.21907226497348453
#       7       SGA-2020 7 ...   0.3623396013552913     0.176289530283184
#      18      SGA-2020 18 ...   0.2435126782700119  0.056979679384652024
#      20      SGA-2020 20 ...  0.40400020366049594    0.2002923725627106
#      24      SGA-2020 24 ...                   --                    --
#      25      SGA-2020 25 ...   0.4801722352399934   0.32037107318891567
#      26      SGA-2020 26 ...   0.1802933994350642   0.06594204465629741
#      29      SGA-2020 29 ...  0.32910023597998006   0.09196551549740958
# ...

# %%
M0r= np.array(SGA_Cindex['R_COG_PARAMS_M0'])
Alpha1r= np.array(SGA_Cindex['R_COG_PARAMS_ALPHA1'])
Alpha2r= np.array(SGA_Cindex['R_COG_PARAMS_ALPHA2'])
Mtotr= np.array(SGA_Cindex['R_COG_PARAMS_MTOT'])
r50 = np.array(SGA_Cindex['r50'])
r0= np.power(10,11)

# %%
g = (-Alpha2r)
l = (r50/r0)
a = (np.power(l,g) * Alpha1r)
m = np.log(1 + a) * M0r
mr50 = Mtotr + m

# %%
M0z= np.array(SGA_Cindex['Z_COG_PARAMS_M0'])
Alpha1z= np.array(SGA_Cindex['Z_COG_PARAMS_ALPHA1'])
Alpha2z= np.array(SGA_Cindex['Z_COG_PARAMS_ALPHA2'])
Mtotz= np.array(SGA_Cindex['Z_COG_PARAMS_MTOT'])
z50 = np.array(SGA_Cindex['z50'])
r0= np.power(10,11)

# %%
b = (-Alpha2z)
c = (z50/r0)
d = (np.power(c,b) * Alpha1z)
f = np.log(1 + d) * M0z
mz50 = Mtotz + f

# %%
print(max(c))
print(min(z50))
# Out:
# inf
# 479052634.90974903

# %%
M0g= np.array(SGA_Cindex['G_COG_PARAMS_M0'])
Alpha1g= np.array(SGA_Cindex['G_COG_PARAMS_ALPHA1'])
Alpha2g= np.array(SGA_Cindex['G_COG_PARAMS_ALPHA2'])
Mtotg= np.array(SGA_Cindex['G_COG_PARAMS_MTOT'])
g50 = np.array(SGA_Cindex['g50'])
r0= np.power(10,11)

# %%
g = (-Alpha2g)
h = (g50/r0)
j = (np.power(h,g) * Alpha1g)
k = np.log(1 + j) * M0g
mg50 = Mtotg + k

# %%
SGA_Cindex.add_column(col= mr50, name ='m(r50)')
SGA_Cindex.add_column(col= mz50, name ='m(z50)')
SGA_Cindex.add_column(col= mg50, name ='m(g50)')

# %%
print(max(mg50))
print(max(mz50))
print(max(mr50))
print(min(mg50))
print(min(mz50))
print(min(mr50))
# Out:
# 45.77439897669265
# 22.02788922407007
# 24.2018391566973
# 8.44173427766982
# 7.6822989271965385
# 8.33055059198148

# %%
g26 = np.array(SGA_Cindex['G_MAG_SB26'])
r26 = np.array(SGA_Cindex['R_MAG_SB26'])
z26 = np.array(SGA_Cindex['Z_MAG_SB26'])

# %%
o = ((mg50-g26)/2.5)
n = np.power(10,o)
deltag = -2.5* np.log(n +1)

# %%
p = ((mz50-z26)/2.5)
q = np.power(10,p)
deltaz = -2.5* np.log(q +1)

# %%
r = ((mr50-r26)/2.5)
s = np.power(10,r)
deltar = -2.5* np.log(s +1)

# %%
deltag_r = deltag - deltar
deltag_z = deltag - deltaz
deltar_z = deltar - deltaz

# %%
SGA_Cindex.add_column(col= deltag_r, name ='Delta(g_r)')
SGA_Cindex.add_column(col= deltag_z, name ='Delta(g_z)')
SGA_Cindex.add_column(col= deltar_z, name ='Delta(r_z)')

# %%
print(max(deltag_r))
print(max(deltag_z))
print(max(deltar_z))
print(min(deltag_r))
print(min(deltag_z))
print(min(deltar_z))
# Out:
# 3.940300715796702
# 3.888552658885466
# 3.8885545825211993
# -4.4973649786921674
# -7.689861926351497
# -5.300946572568778

# %%
SGA_Cindex
# Out:
# <Table length=383620>
#  SGA_ID    SGA_GALAXY    ...       Delta(g_z)             Delta(r_z)
#  int64      bytes16      ...        float64                float64
# ------- ---------------- ... ---------------------- ----------------------
#       2       SGA-2020 2 ...   0.009133917515395051 -0.0006801091890804578
#       3       SGA-2020 3 ...  0.0013769916708179508  -0.014103951656333713
#       4       SGA-2020 4 ...  -0.027904771594295497   -0.03350873008480271
#       7       SGA-2020 7 ...   0.015393382981958581  -0.001935795122303574
#      18      SGA-2020 18 ...    0.10415140435072878     0.1078308552349383
#      20      SGA-2020 20 ...    0.09213137370497515    0.09035785589441492
#      24      SGA-2020 24 ...                    nan                    nan
#      25      SGA-2020 25 ...   0.024965678960955362   0.012910132374838401
#      26      SGA-2020 26 ...    0.17816410210935407    0.19130180643981243
# ...

# %%
SGA_Cindex.write('SGA_CG.fits', overwrite = True)

# %%
plt.hist(deltag_r, bins=900)
plt.xlim([-0.2,0.2])
plt.title('delta(g_r)')
plt.ylabel('Counts')
plt.xlabel('deltag_r value')
plt.show()
plt.close()

# %%
plt.hist(deltag_r, bins=900)
plt.xlim([-0.2,0.2])
plt.title('delta(g_z)')
plt.ylabel('Counts')
plt.xlabel('deltag_z value')
plt.show()
plt.close()

# %%
plt.hist(deltag_r, bins=900)
plt.xlim([-0.2,0.2])
plt.title('delta(r_z)')
plt.ylabel('Counts')
plt.xlabel('deltar_z value')
plt.show()
plt.close()
