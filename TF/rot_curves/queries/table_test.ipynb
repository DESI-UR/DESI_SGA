# %%
from astropy.table import Table
import numpy as np

# %%
t = Table.read('/pscratch/sd/n/nravi/pv_rot_curves/pv_tf_rotcurve_targets_iron_1.fits', format='fits')

# %%
t
# Out:
# <Table length=1192>
#      TARGETID     TILEID SGA_ID ...  STD_FIBER_RA STD_FIBER_DEC SPECTYPE
#       int64       int64  int64  ...    float64       float64     bytes6
# ----------------- ------ ------ ... ------------- ------------- --------
# 39632976639689952  23399   4075 ...           0.0           0.0   GALAXY
# 39633321881240937  20600   1961 ...    0.02903579   0.056157745   GALAXY
# 39633321881240937  20600   1961 ...           0.0           0.0   GALAXY
# 39633321881240937  81060   1961 ...    0.02903579   0.056157745   GALAXY
# 39633321881240937  81060   1961 ...           0.0           0.0   GALAXY
# 39633191518077188  23766   2336 ...           0.0           0.0   GALAXY
# 39627755171613008  23802   6075 ...           0.0           0.0   GALAXY
# 39628442961972368  22928   8048 ...      0.063568    0.14582789   GALAXY
# 39627763413421614  22042   7246 ...           0.0           0.0   GALAXY
# 39089837390700859  82636   3106 ...   0.020011231   0.037597857   GALAXY
# ...
