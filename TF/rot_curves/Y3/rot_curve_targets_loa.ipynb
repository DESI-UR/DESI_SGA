# %%
import numpy as np

from astropy.table import Table, vstack
from astropy.coordinates import SkyCoord
from astropy import units as u

import matplotlib.pyplot as plt

#from astropy.io import fits

from tqdm import tqdm

import glob

# %% [markdown]
# # Table Initializations

# %%
# tf_loa=Table.read('/global/cfs/projectdirs/desi/science/td/pv/tfgalaxies/Y3/desi_pv_loa_healpix.fits')
# tf_loa[:5]

# %%
# tf_fuji = Table.read('/global/cfs/cdirs/desi/science/td/pv/tfgalaxies/desi_pv_tf_fuji_healpix.fits')
# tf_fuji[:5]

# %%
shredded_list = list(glob.glob('/pscratch/sd/n/nravi/fastspecfit_shredded/*.fits'))

shredded_tables = [Table.read(x) for x in shredded_list]

shredded = vstack(shredded_tables)

# shredded = vstack(shredded_tables, metadata_conflicts = 'silent')
shredded[:5]
# Out:
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='DbmCGZkCDbkCDZkC' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='2162565475' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='Pk6fQh4cPh4cPh4c' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='1309126199' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='oAHMr4GJo9GJo9GJ' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='243793329' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='ZnYAcnX3ZnX9bnX9' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='1729674683' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='CVL8FSL6CSL6CSL6' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='2656849770' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='FEUDIDUBFDUBFDUB' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='3544391522' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='0JV709V70GV709V7' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='3963311263' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='REJ7RDG6RDG6RDG6' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='3665123127' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='9aA3EX129a82CW82' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='3249201731' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='PAalP9UlPAZlP9Zl' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='204569641' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='JaASJT5QJYAQJY5Q' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='2159466839' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='DN9IEK6GDK6GDK6G' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='3919809061' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='UARiV4RZU9RfU9RZ' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='257401372' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='XE4AZ936XE3AX933' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='4023269888' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='dk7bej6Zdj6bdj6Z' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='1019196137' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='7F4679447C447944' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='564449878' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='53DHA1CE61CEA1CE' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='1082922373' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='Cgc2DeZ2Ceb2CeZ2' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='1612541260' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='eaFFhR9DeXEDeX9D' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='2208435428' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='Y55ac44RZ44Xa44X' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='736079089' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='U7g2a5f2X5f2a5f2' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='470375926' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='9gNIDeL99eLGAeL9' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='1899667528' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='OBa4PAV4OAZ4OAZ4' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='4062930211' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='A5cGA5a9A5aGA5a9' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='1357684800' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='Z1pRa1nRV1nRZ1nR' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='672129288' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='ee4RhZ3Qeb3QeZ3Q' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='2897637025' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='HJ38J936HG36H936' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='4240266065' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='nEf6n9f3nCf3n9f3' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='4009710269' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='W9iDX9g9W9gAW9g9' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='402206240' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='3N0aAN0Z3N0aAN0W' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='3622257228' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='GASDH2R9G9RAG9R9' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='358103628' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='MOEAOME4MME9MME9' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='3062186564' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='STNAUQL1SQL8SQL8' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='2607303217' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='TTnTUSkTTSkTTSkT' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='3485686758' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='JHaDM9W9JEaCJ9W9' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='70071621' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='mSfFmRfDmRfDmRfD' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='2702638277' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='FHBWI99WFGAWF99W' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='582835490' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'CHECKSUM' types <class 'str'> and <class 'str'>, choosing CHECKSUM='99fDA9f949fA99f9' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'DATASUM' types <class 'str'> and <class 'str'>, choosing DATASUM='352728208' [astropy.utils.metadata.merge]
# <Table length=5>
#     TARGETID     SURVEY PROGRAM ... MW_TRANSMISSION_W3 MW_TRANSMISSION_W4 SGA_ID
#      int64       bytes7  bytes6 ...      float32            float32       int64
# ---------------- ------ ------- ... ------------------ ------------------ ------
# 1084427169955849    sv3    dark ...          0.9996844          0.9998808 556089
# 1084434300272644    sv3    dark ...         0.99979657         0.99992317 375898
# 1084427178344451    sv3    dark ...          0.9997765          0.9999156  21266
# 1084434300272643    sv3    dark ...         0.99979717          0.9999234 375898
# 1084427178344450    sv3    dark ...         0.99977666         0.99991566  21266

# %%
# take only the columns I need, and renaming them to match code already written

tf_loa = shredded[['TARGETID', 'SGA_ID', 'RA', 'DEC', 'Z', 'Z_RR', 'ZWARN', 'DELTACHI2']]
tf_loa.rename_column('RA', 'TARGET_RA')
tf_loa.rename_column('DEC', 'TARGET_DEC')
tf_loa.rename_column('Z_RR', 'Z_ERR')
tf_loa[:5]
# Out:
# <Table length=5>
#     TARGETID     SGA_ID     TARGET_RA      ... ZWARN     DELTACHI2
#      int64       int64       float64       ... int64      float64
# ---------------- ------ ------------------ ... ----- ------------------
# 1084427169955849 556089 242.72318746350186 ...     0  789.0584922824055
# 1084434300272644 375898 243.65642926326169 ...     0  310.9083716990426
# 1084427178344451  21266 243.62537013307835 ...     0  849.3460895419121
# 1084434300272643 375898 243.65118121249577 ...     0 1123.4490712519037
# 1084427178344450  21266 243.62044993111272 ...     0  2463.962895900011

# %% [markdown]
# # SGA Table

# %%
SGA = Table.read('/global/cfs/cdirs/cosmo/data/sga/2020/SGA-2020.fits', 'ELLIPSE')
SGA[:5]
# Out:
# <Table length=5>
# SGA_ID  SGA_GALAXY          GALAXY         ... Z_COG_PARAMS_CHI2 ELLIPSEBIT
# int64    bytes16           bytes29         ...      float32        int32
# ------ ----------- ----------------------- ... ----------------- ----------
#      2  SGA-2020 2              PGC1283207 ...       0.011723555          0
#      3  SGA-2020 3              PGC1310416 ...        0.20391206          0
#      4  SGA-2020 4 SDSSJ145059.93+135143.0 ...         1.8054093          0
#      7  SGA-2020 7              PGC1742504 ...       0.004725194          0
#     18 SGA-2020 18  2MASXJ12340801+4535444 ...       0.028653827          0

# %%
SGA_dict = {}
for i in range(len(SGA)):
    SGA_dict[SGA['SGA_ID'][i]] = i

# %% [markdown]
# # Distances of SGA observations

# %%
#creates empty columns to add to tf_loa for classifications
# projected distance between center and fiber
tf_loa['DIST'] = np.nan

# normalized distance between center and fiber
tf_loa['DIST_R26'] = np.nan

# pa of major axis
tf_loa['PA'] = np.nan

# position angle between center point and fiber
tf_loa['C_TO_F_ANGLE'] = np.nan

# position angle of fiber and major axis
tf_loa['ANGLE_OFF_AXIS'] = np.nan

for i in tqdm(np.unique(tf_loa['SGA_ID'])):

    #identify all galaxy targets
    targ_id = tf_loa['SGA_ID'] == i

    #find the index for this target in SGA
    sga_id = SGA_dict[i]
    
#------------------------------------------
#find the coordinates of center of galaxy
#------------------------------------------
    SGA_coords = SkyCoord(ra=SGA['RA'][sga_id], 
                          dec=SGA['DEC'][sga_id], 
                          unit=u.degree)
    
#---------------------------------------------------   
#find the coordinates of all the targets on galaxy
#---------------------------------------------------  
    target_coords = SkyCoord(ra=tf_loa['TARGET_RA'][targ_id], 
                             dec=tf_loa['TARGET_DEC'][targ_id], 
                             unit=u.degree)
    
    # separation between center and fiber (in deg)
    sep2d = target_coords.separation(SGA_coords)
    
#---------------------------------
# find if fiber is on major axis
#---------------------------------
    
    # position angle of semimajor axis
    pa = SGA['PA'][sga_id]*u.deg

    # position angle between center and fiber
    theta = SGA_coords.position_angle(target_coords).to(u.deg).value

    # angle between semimajor axis and fiber
    sep_angle = theta - pa.value

    # replace all points in center with 0
    sep_angle = abs(np.where(theta == 0, 0, sep_angle))

    # replace all angles close to 180 or 0 with 0 --------------------------------------------
    tol = (np.isclose(sep_angle, 0, atol = 1e-4)) | (np.isclose(sep_angle, 180, atol = 1e-4))

    sep_angle[tol] = 0
    #-------------------------------------------------------------------------------------------

    #print('pa: ', pa.value,'theta: ', theta,'sep: ', sep_angle)

    # distance to center of galaxy
    tf_loa['DIST'][targ_id] = sep2d
    
    # distance to target coordinates (in units R26)
    tf_loa['DIST_R26'][targ_id] = 2*sep2d.to('arcmin')/(SGA['D26'][sga_id]*u.arcmin)

    tf_loa['C_TO_F_ANGLE'][targ_id] = theta
    
    tf_loa['ANGLE_OFF_AXIS'][targ_id] = sep_angle

    tf_loa['PA'][targ_id] = pa
# Out:
# 100%|██████████| 227769/227769 [13:38<00:00, 278.43it/s]

# %%
tf_loa[:50]
# Out:
# <Table length=50>
#      TARGETID      SGA_ID ...    C_TO_F_ANGLE      ANGLE_OFF_AXIS
#       int64        int64  ...      float64            float64
# ----------------- ------- ... ------------------ ------------------
#  1084427169955849  556089 ...  224.0717662682332                0.0
#  1084434300272644  375898 ...  54.93254783937784                0.0
#  1084427178344451   21266 ... 111.70044970679623                0.0
#  1084434300272643  375898 ... 234.93254783934097                0.0
#  1084427178344450   21266 ...   291.700449706759                0.0
#  1084423579631621  586736 ... 31.067515174170115                0.0
#  1084434300272642  375898 ... 234.93254783935032                0.0
#  1084434312855561  867518 ... 12.041849274348749                0.0
#  1084437831876610  967351 ... 301.25479055775673                0.0
#               ...     ... ...                ...                ...
# 39633315476538458  297070 ... 21.693573720781316 113.15640186515618
#  1084441308954633 1108706 ...  73.19335903954601                0.0
#  1084434275106817  396464 ... 190.00195668454623                0.0
#  1084434270912517 1374964 ... 245.91617589301734                0.0
# 39633311936547489 1310962 ... 199.09643785311846 110.48298112704424
#  1084441308954632 1108706 ... 253.19335903885133                0.0
#  1084434275106818  396464 ... 190.00195668442083                0.0
#  1084437798322180   26866 ...  34.66130839971483                0.0
#  1084434266718223  265633 ...  305.3376188427156                0.0
#  1084434266718225  265633 ... 125.33761884322941                0.0

# %% [markdown]
# # Selecting galaxies
#
# Viable galaxies either have </br>
# a) 1 center + 2 unique points </br>
# b) No center point, but 10 unique points </br>
# c) Two symmetric points + 1 unique point

# %%
#target distance that can be considered in center
#units R26
center_dist_lim = 0.001

#minimum distance between two targets to be considered unique
#units R26
unique_dist_lim = 0.01

# %%
#empty column to classify galaxy
tf_loa['Selection'] = 0

#for each unique SGA ID
for i in tqdm(np.unique(tf_loa['SGA_ID'])):

    #identify all the galaxies and targets
    obs_id = np.logical_and(tf_loa['SGA_ID'] == i, tf_loa['TARGETID'] > 0)
    #logical_and returns if both statements are true
    
    #makes a table of the targets corresponding to this galaxy
    obs = tf_loa[obs_id]

    sga_id = SGA_dict[i] 

#if the galaxy has more than three observations
    if len(obs) >= 3:

        # identify all points on semimajor axis
        on_major = obs[obs['ANGLE_OFF_AXIS'] == 0]

        # find number of unique points on axis
        if len(on_major) == 0:
            unique_on = 0

        else:
            on_major['DIST_R26'] = np.round(on_major['DIST_R26'], 6)
            on_major = on_major.group_by('DIST_R26')
            unique_on = len(on_major.groups)
        
        # identify all points off major axis
        off_major = obs[obs['ANGLE_OFF_AXIS'] != 0]

        # find number of unique points off axis
        num_off_major = len(off_major)

        if num_off_major == 0:
            unique_off = 0
        else:
            off_major = off_major.group_by(['DIST_R26','ANGLE_OFF_AXIS'])
            unique_off = len(off_major.groups)

#-----
# a
#-----
        #check to see if there is a center observation
        if np.any(on_major['DIST_R26'] <= center_dist_lim):

            # check how many unique points on semimajor axis
            not_center = on_major[on_major['DIST_R26'] > unique_dist_lim]

            if len(not_center) >= 2 and (np.max(not_center['DIST_R26']) - np.min(not_center['DIST_R26'])) >= unique_dist_lim:
                
                #since there 2 unique points, classify it as viable galaxy
                tf_loa['Selection'][obs_id] = 1

            # check how many points off semimajor axis
            elif (len(not_center) >= 1) and (num_off_major >= 1):
                tf_loa['Selection'][obs_id] = 1

            elif num_off_major >= 2:
                tf_loa['Selection'][obs_id] = 1

#----
# b
#----

        elif unique_on + unique_off >= 10:
            tf_loa['Selection'][obs_id] = 1
            # print(sga_id,': on axis:', on_major['DIST_R26'], len(on_major.groups))
            # print(sga_id,': off axis:', off_major['DIST_R26'], off_major['ANGLE_OFF_AXIS'], unique_off)
#----
# c
#----
        #since there isn't a center observation
        elif len(on_major) > 0:
            
            #split targets on semimajor axis onto either side of center galaxy
            if (SGA['PA'][sga_id] < 45) or (SGA['PA'][sga_id] > 135):

                left_index = on_major['TARGET_DEC'] - SGA['DEC'][sga_id] > 0

            else:
                left_index = on_major['TARGET_RA'] - SGA['RA'][sga_id] > 0
                
            left = on_major[left_index]
            right = on_major[~left_index]

            if len(left) > 0 and len(right) > 0:

                for j in range(len(left)):
                    
                    # check that there are 2 symmetric observations
                    if np.any(np.abs(right['DIST_R26'] - left['DIST_R26'][j]) < unique_dist_lim):

                    #check if there is a third point
                        if (np.any(np.abs(right['DIST_R26'] - left['DIST_R26'][j]) > unique_dist_lim) 
                            or np.any(np.abs(left['DIST_R26'] - left['DIST_R26'][j]) > unique_dist_lim)
                            or (num_off_major != 0)):

                            #viable galaxy
                            tf_loa['Selection'][obs_id] = 1
                            
    # if tf_loa['Selection'][obs_id][0] == 1:
    #     print(obs['SGA_ID'][0])

print(len(tf_loa[tf_loa['Selection']==1]))
# Out:
# 100%|██████████| 227769/227769 [17:18<00:00, 219.33it/s]
# 115256

# %% [markdown]
# ## Save Viable Galaxies

# %%
print(len(tf_loa[tf_loa['Selection']==1]))
loa_targs = (tf_loa[tf_loa['Selection']==1])
len(np.unique(loa_targs['SGA_ID']))
# Out:
# 115256
# 21443

# %%
loa_targs.write('/pscratch/sd/d/dbustos/rot_curves/loa_targs_v2.fits',format='fits',overwrite=True)

# %% [markdown]
# ## old code before shredded galaxies

# %%
# #creates empty columns to add to tf_loa for classifications
# tf_loa['DIST'] = np.nan
# tf_loa['DIST_R26'] = np.nan

# for i in tqdm(np.unique(tf_loa['SGA_ID'])):

#     #identify all gaalxy targets
#     targ_id = tf_loa['SGA_ID'] == i

#     #find the index for this target in SGA
#     sga_id = SGA_dict[i]

#     #find the coordinates of center of galaxy
#     SGA_coords = SkyCoord(ra=SGA['RA'][sga_id], 
#                           dec=SGA['DEC'][sga_id], 
#                           unit=u.degree)
    
#     #find the coordinates of all the targets on galaxy
#     target_coords = SkyCoord(ra=tf_loa['TARGET_RA'][targ_id], 
#                              dec=tf_loa['TARGET_DEC'][targ_id], 
#                              unit=u.degree)

#     sep2d = target_coords.separation(SGA_coords)

#     #distance to center of galaxy
#     tf_loa['DIST'][targ_id] = sep2d
#     #distance to target coordinates
#     tf_loa['DIST_R26'][targ_id] = 2*sep2d.to('arcmin')/(SGA['D26'][sga_id]*u.arcmin)

# %%
#empty column to classify galaxy
tf_loa['Selection'] = 0

#for each unique SGA ID
for i in tqdm(np.unique(tf_loa['SGA_ID'])):

    #identify all the galaxies and targets
    obs_id = np.logical_and(tf_loa['SGA_ID'] == i, tf_loa['TARGETID'] > 0)
    #logical_and returns if both statements are true
    
    #makes a table of the targets corresponding to this galaxy
    obs = tf_loa[obs_id]

    sga_id = SGA_dict[i] 

#if the galaxy has more than three observations
    if len(obs) >= 3:

#-----
# a
#-----
        #check to see if there is a center observation
        if np.any(obs['DIST_R26'] < center_dist_lim):

            #since there is a center observation, check if there are two unique points
            not_center = obs[obs['DIST_R26'] > unique_dist_lim]

            if len(not_center) >= 2 and (np.max(not_center['DIST_R26']) - np.min(not_center['DIST_R26'])) >= unique_dist_lim:

                #since there 2 unique points, classify it as viable galaxy
                tf_loa['Selection'][obs_id] = 1
#----
# b
#----
        #since there isn't a center observation
        else:
            
            #split targets into above and below SGA declination
            if (SGA['PA'][sga_id] < 45) or (SGA['PA'][sga_id] > 135):

                left_index = obs['TARGET_DEC'] - SGA['DEC'][sga_id] > 0

            else:
                left_index = obs['TARGET_RA'] - SGA['RA'][sga_id] > 0
                
            left = obs[left_index]
            right = obs[~left_index]

            if len(left) > 0 and len(right) > 0:

                for j in range(len(left)):
                    
                    # check that there are 2 symmetric observations
                    if np.any(np.abs(right['DIST_R26'] - left['DIST_R26'][j]) < unique_dist_lim):

                    #check if there is a third point
                        if (np.any(np.abs(right['DIST_R26'] - left['DIST_R26'][j]) > unique_dist_lim)
                        or np.any(np.abs(left['DIST_R26'] - left['DIST_R26'][j]) > unique_dist_lim)):

                            #viable galaxy
                            tf_loa['Selection'][obs_id] = 1

print(len(tf_loa[tf_loa['Selection']==1]))
# Out:
# 100%|██████████| 227769/227769 [09:09<00:00, 414.15it/s]
# 109292
