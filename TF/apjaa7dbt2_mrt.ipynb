# %% [markdown]
# # Table of Galaxy Groups Below 3500 km s$^{-1}$
#
# Parse the table of galaxy groups at low redshift from [Kourkchi and Tully (2017)](https://iopscience.iop.org/article/10.3847/1538-4357/aa76db#apjaa76dbt2).

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from astropy.table import Table
from astropy.coordinates import SkyCoord

# %%
mpl.rc('font', size=14)

# %% [markdown]
# ## Read the Data
#
# See the text file for the format info. Need to use the `fixed_width_no_header` format with column start positions (FORTRAN-style output).

# %%
groups = Table.read('apjaa76dbt2_mrt.txt',
                    format='ascii.fixed_width_no_header',
                    names=['PGC1', 'PGC1+', 'Mem', 'GLON', 'GLAT', 'SGL', 'SGB', 'Ksmag', 'logK', 'Vh', 'VLS', 'ND', 'D', 'errD', 'sigmaL', 'sigmaV', 'R2t', 'Rg', 'logMk', 'logMd'],
                    col_starts=np.asarray([1, 9, 17, 21, 30, 39, 48, 57, 63, 69, 74, 79, 83, 89, 92, 96, 100, 106, 112, 119])-1,
                   )

# %%
groups
# Out:
# <Table length=8826>
#   PGC1   PGC1+   Mem    GLON     GLAT   ...   R2t      Rg    logMk   logMd
#  int64   int64  int64 float64  float64  ... float64 float64 float64 float64
# ------- ------- ----- -------- -------- ... ------- ------- ------- -------
#   43296   43296   191 302.2241  21.6465 ...   1.612   0.893  14.624  14.717
#   46618   43296    30 307.8738  19.2865 ...    0.95   0.745  13.936  13.808
#   45174   43296    34 306.0424  32.5707 ...   0.833   0.693  13.764  13.756
#   40498   43296    24 297.5648  23.0823 ...   0.801   0.607  13.713  13.207
#   43557   43296    22 302.9333  36.4075 ...   0.724   0.428  13.582  13.017
#   46409   43296    12 307.9495  14.9305 ...   0.659   0.399  13.459  13.045
#   45466   43296    22  307.803  38.9261 ...   0.544   0.444   13.21  12.747
#   49424   43296     7 313.8107  13.0725 ...   0.513   0.391  13.134  12.782
#   49106   43296     8 312.8342  12.8475 ...   0.507   0.204  13.117  12.243
#   41960   43296     7 299.5259  22.9197 ...   0.498   0.467  13.093  12.966
#   39212   43296     6 294.6965  26.7989 ...   0.491   0.275  13.076  12.812
#   49673   43296     5 315.3064  17.3118 ...   0.473   0.164  13.025  10.609
#   35417   43296     8 285.0291   23.609 ...   0.459    0.27  12.989  12.556
#   46029   43296     5 306.9907  16.5572 ...   0.433   0.368  12.911  10.822
#   47582   43296     6 312.5699  28.8934 ...    0.43   0.175  12.902  12.049
#   45999   43296     1 306.6879  13.2287 ...   0.401      --   12.81      --
#   46828   43296     4 310.8477  30.0461 ...   0.395   0.089  12.791  11.279
#   37334   43296     1 291.1344  21.6874 ...    0.38      --  12.741      --
#   44361   43296     1 304.2594  23.0937 ...    0.37      --  12.706      --
#   43642   43296     1 303.1343  33.0309 ...   0.366      --  12.692      --
#   44340   43296     3 304.7882  35.5047 ...   0.361   0.224  12.674  12.684
#     ...     ...   ...      ...      ... ...     ...     ...     ...     ...
# 2801026 2801026     1  83.8788  44.4092 ...   0.041      --   9.848      --
# 5056945 5056945     1 143.0908  40.3956 ...   0.041      --   9.852      --
# 2807157 2807157     1 109.0931 -22.3774 ...   0.037      --   9.705      --
# 5059187 5059187     1 222.9204  82.4066 ...    0.04      --   9.799      --
# 2807150 2807150     1 339.0452  62.6038 ...    0.04      --   9.801      --
# 2543081 2543081     1 137.2321  58.9793 ...   0.035      --   9.642      --
# 5059698 5059698     1 205.0185  58.4086 ...   0.037      --    9.71      --
# 5059815 5059815     1 107.2803  -45.993 ...   0.037      --   9.707      --
# 4017109 4017109     1 182.0749  36.1668 ...   0.036      --   9.688      --
# 4581796 4581796     1 348.4887 -65.0808 ...   0.035      --   9.634      --
# 2806961 2806961     1 214.7249    36.94 ...   0.034      --   9.593      --
#  166185  166185     1  63.7123  71.9922 ...   0.032      --   9.512      --
# 5060050 5060050     1  208.951  14.4227 ...   0.033      --   9.563      --
#   38998   38998     1 192.2144  81.1916 ...   0.033      --   9.553      --
# 5065058 5065058     1 219.6379  54.4354 ...   0.033      --   9.571      --
# 4577740 4577740     1 211.0386  31.6633 ...   0.031      --   9.491      --
# 4088225 4088225     1 221.5565  35.4033 ...   0.027      --   9.292      --
#  166121  166121     1 136.3741  61.1774 ...   0.027      --   9.288      --
# 5072714 5072714     1 164.1404 -38.8323 ...    0.02      --   8.879      --
# 5072715 5072715     1  195.661  -9.3213 ...   0.019      --   8.832      --
# 5072710 5072710     1 108.5234   -51.03 ...   0.017      --   8.726      --

# %% [markdown]
# ## Select Groups with Many Members
#
# Plot the groups with:
# * At least 20 members.
# * A distance with uncertainty below 25%.

# %%
select = (groups['Mem'] >= 20) & (groups['errD']/groups['D'] < 0.25)

# %%
fig, axes = plt.subplots(1,2, figsize=(10,4), tight_layout=True)
ax = axes[0]
ax.hist(groups['D'][select])
ax.set(xlabel='distance [Mpc]',
       xlim=(0,60),
       ylabel='count')
ax = axes[1]
ax.errorbar(groups['D'][select], groups['VLS'][select], xerr=groups['errD'][select], fmt='o')
ax.set(xlabel='distance [Mpc]',
       xlim=(0,60),
       ylabel='$V_{LS}$ km s${-1}$',
       ylim=(0,3600));

# %%
def plot_radec(coords, dist):
    """Mollweide projection plot adapted to astro coordinates.
    
    Parameters
    ----------
    table : astropy.table.Table
        Data table with secondary target info.
    
    Returns
    -------
    coords : ndarray
        Array of SkyCoords.
    mag : ndarray
        Array of optical magnitudes.
    classified : ndarray
        True if classification is available.
    """
    fig, ax = plt.subplots(1,1, figsize=(12,6), subplot_kw={'projection': 'mollweide'})
    _ra = np.radians(120) - coords.ra.to_value('rad')
    _ra[_ra < -np.pi] += 2*np.pi
    _dec = coords.dec.to_value('rad')

    sc = ax.scatter(_ra, _dec, s=5000/dist**2, cmap='magma', alpha=0.7)

    # Clean up the plot and return the Figure object.
    ax.set(xticks=np.radians([-150, -120, -90, -60, -30, 0, 30, 60, 90, 120, 150]),
           xticklabels=['270', '240', '210', '180', '150', '120', '90', '60', '30', '0', '330'])
    ax.tick_params(axis='x', labelsize=10)
    ax.tick_params(axis='y', labelsize=10)
    ax.grid(ls=':')
    
    return fig;

# %% [markdown]
# ## Plot Group Positions
#
# Plot the groups' RA and Dec. Make the size of the marker proportional to 1/(distance)$^2$.

# %%
coords = SkyCoord(l=groups['GLON'][select], b=groups['GLAT'][select], unit='deg', frame='galactic').transform_to('icrs')
dist = groups['D'][select]

# %%
fig = plot_radec(coords, dist)
